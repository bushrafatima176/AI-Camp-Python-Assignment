# %%
#Make a calculator using Python with addition , subtraction , multiplication,division and power.

val1 = int(input("Enter first value : "))
val2 = int(input("Enter second value : "))
operand = input("Enter your operator : ")

if operand == "+":
    result = val1 + val2
    print("Addition : " , result)
elif operand == "-":
    result = val1 - val2
    print("Subtraction :" , result)
elif operand == "*":
    result = val1 * val2
    print("Multiplication : " , result)
elif operand == "/":
    result = val1 / val2
    print("Division : " , result)
elif operand == "^":
    result = val1 ** val2
    print("Power :" , result)
else:
    print("Please enter correct operator")
# Out:
# Enter first value :  6
# Enter second value :  7
# Enter your operator :  -
# Subtraction : -1

# %%
#Write a program to check if there is any numeric value in list using for loop
val1 = ["Bushra",45,"Fatima","Ayesha","Maria"]
val2 = []
for i in val1:
    if type(i) == int:
        val2.append(i)
print(val2)
# Out:
# [45]

# %%
#Write a Python script to add a key to a dictionary

dic= { "Name":"Bushra", "Age":"22","Rollno" : "2222"}
print(dic)
# Out:
# {'Name': 'Ali', 'Age': '22', 'Rollno': '2222'}

# %%
dic ["Father Name"] = "Shoukat"
print(dic)
# Out:
# {'Name': 'Ali', 'Age': '22', 'Rollno': '2222', 'Father Name': 'Shoukat'}

# %%
#Write a Python program to sum all the numeric items in a dictionary

d={'ONE':5,'TWO':35,'THREE':3}
sum=0
for i ,j in d.items():
    sum=sum+j
print(sum)
# Out:
# 43

# %%
#Write a program to identify duplicate values from list

l=[1,2,3,4,5,3,4,5,2,4,8,8,7,6]
size=len(l)
repeated=[]
for i in range(size):
    k = i + 1
    for j in range (k,size):
        if l[i]== l[j] and l[i] not in repeated:
            repeated.append(l[i])
print(repeated)
# Out:
# [2, 3, 4, 5, 8]

# %%
#Write a Python script to check if a given key already exists in a dictionary

dic={'Name':'Bushra','Age':'20','Roll-Num':234}
n=input("Enter a key: ")
for i,j in dic.items():
    if n==i:
        print("key is exist already")
        break
    else:
        print("New key is = ",n)
        break
# Out:
# Enter a key:  Name
# key is exist already
